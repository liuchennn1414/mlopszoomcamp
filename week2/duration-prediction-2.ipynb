# %%
import pandas as pd
import pickle
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.metrics import root_mean_squared_error

# %% [markdown]
# # Set up MLFLOW

# %%
import mlflow 

mlflow.set_tracking_uri("sqlite:///mlflow.db")# set tracking url 
mlflow.set_experiment("nyc-taxi-experiment-2") # create the experiment
# Out:
# 2025/06/29 03:30:25 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2025/06/29 03:30:25 INFO mlflow.store.db.utils: Updating database tables
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# <Experiment: artifact_location='/workspaces/mlopszoomcamp/week2/mlruns/3', creation_time=1751166863075, experiment_id='3', last_update_time=1751166863075, lifecycle_stage='active', name='nyc-taxi-experiment-2', tags={}>

# %%
df = pd.read_parquet('https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-01.parquet')

df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

df = df[(df.duration >= 1) & (df.duration <= 60)]

categorical = ['PULocationID', 'DOLocationID']
numerical = ['trip_distance']

df[categorical] = df[categorical].astype(str)

# %%
train_dicts = df[categorical + numerical].to_dict(orient='records')

dv = DictVectorizer()
X_train = dv.fit_transform(train_dicts)

target = 'duration'
y_train = df[target].values

lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_train)

root_mean_squared_error(y_train, y_pred)
# Out:
# 9.838799799829577

# %%
def read_dataframe(filename):
    if filename.endswith('.csv'):
        df = pd.read_csv(filename)

        df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
        df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    elif filename.endswith('.parquet'):
        df = pd.read_parquet(filename)

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
df_train = read_dataframe('https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-01.parquet')
df_val = read_dataframe('https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-02.parquet')

# %%
len(df_train), len(df_val)
# Out:
# (73908, 61921)

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
categorical = ['PU_DO'] #'PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

root_mean_squared_error(y_val, y_pred)
# Out:
# 7.758715209663881

# %%
with open('models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

# %%
with mlflow.start_run():
    alpha = 0.01
    lr = Lasso(alpha)
    lr.fit(X_train, y_train)
    y_pred = lr.predict(X_val)
    rmse = root_mean_squared_error(y_val, y_pred)
    
    # Manual logging - more reliable
    mlflow.log_param("alpha", alpha)
    mlflow.log_metric("rmse", rmse)
    mlflow.sklearn.log_model(lr, "lasso_model")
# Out:
# 2025/06/29 03:30:37 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/06/29 03:30:39 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.

# %% [markdown]
# # Hyperparameter tuning with mlflow

# %%
import xgboost as xgb

# %%
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params): # hyperopt objective function 
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost") # every run during tuning is recorded to find best parameters 
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = root_mean_squared_error(y_val, y_pred)
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

# %%
# search_space = {
#     'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
#     'learning_rate': hp.loguniform('learning_rate', -3, 0),
#     'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
#     'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
#     'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
#     'objective': 'reg:linear',
#     'seed': 42
# }

# best_result = fmin(
#     fn=objective,
#     space=search_space,
#     algo=tpe.suggest,
#     max_evals=50,
#     trials=Trials()
# )

# %% [markdown]
# # Best Model
# You can sort all record by desc rmse to find the pair of best parameters, then train the model using the parameters, save the model and log the training in mlflow. This time, instead of adding tags, we will use auto log

# %%
params = {
    'learning_rate': 0.1557567395831292,
    'max_depth': 10,
    'min_child_weight': 1.716416307091764,
    'objective': 'reg:linear',
    'eval_metric': 'rmse',  # Add this line
    'reg_alpha': 0.027589494435073993,
    'reg_lambda': 0.05813256739773465,
    'seed': 42
}

# Disable model logging in autolog, then log manually
mlflow.xgboost.autolog(log_datasets=False, log_models=False)

with mlflow.start_run():
    booster = xgb.train(
        params=params,
        dtrain=train,
        num_boost_round=1000,
        evals=[(valid, 'validation')],
        early_stopping_rounds=50
    )
    
    # Log model with custom name
    mlflow.xgboost.log_model(booster, "XGBoost_Model")
    # Manual RMSE calculation and logging
    y_pred = booster.predict(valid)
    rmse = root_mean_squared_error(valid.get_label(), y_pred)
    mlflow.log_metric("rmse", rmse)
# Out:
# /home/codespace/anaconda3/envs/week2-env/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [03:41:21] WARNING: /workspace/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:10.99990
# [1]	validation-rmse:10.03189
# [2]	validation-rmse:9.26994
# [3]	validation-rmse:8.67609
# [4]	validation-rmse:8.21642
# [5]	validation-rmse:7.86089
# [6]	validation-rmse:7.59085
# [7]	validation-rmse:7.38312
# [8]	validation-rmse:7.22599
# [9]	validation-rmse:7.10573
# [10]	validation-rmse:7.01421
# [11]	validation-rmse:6.94278
# [12]	validation-rmse:6.88631
# [13]	validation-rmse:6.84316
# [14]	validation-rmse:6.80932
# [15]	validation-rmse:6.78308
# [16]	validation-rmse:6.76281
# [17]	validation-rmse:6.74500
# [18]	validation-rmse:6.73210
# [19]	validation-rmse:6.72066
# [20]	validation-rmse:6.71122
# [21]	validation-rmse:6.70148
# [22]	validation-rmse:6.69493
# [23]	validation-rmse:6.69017
# [24]	validation-rmse:6.68575
# [25]	validation-rmse:6.68172
# [26]	validation-rmse:6.67870
# [27]	validation-rmse:6.67550
# [28]	validation-rmse:6.67444
# [29]	validation-rmse:6.67192
# [30]	validation-rmse:6.67075
# [31]	validation-rmse:6.66982
# [32]	validation-rmse:6.66859
# [33]	validation-rmse:6.66760
# [34]	validation-rmse:6.66669
# [35]	validation-rmse:6.66601
# [36]	validation-rmse:6.66283
# [37]	validation-rmse:6.66143
# [38]	validation-rmse:6.65992
# [39]	validation-rmse:6.65853
# [40]	validation-rmse:6.65715
# [41]	validation-rmse:6.65641
# [42]	validation-rmse:6.65561
# [43]	validation-rmse:6.65459
# [44]	validation-rmse:6.65375
# [45]	validation-rmse:6.65248
# [46]	validation-rmse:6.65134
# [47]	validation-rmse:6.65079
# [48]	validation-rmse:6.64995
# [49]	validation-rmse:6.64865
# [50]	validation-rmse:6.64730
# [51]	validation-rmse:6.64598
# [52]	validation-rmse:6.64529
# [53]	validation-rmse:6.64455
# [54]	validation-rmse:6.64339
# [55]	validation-rmse:6.64208
# [56]	validation-rmse:6.64098
# [57]	validation-rmse:6.64045
# [58]	validation-rmse:6.63931
# [59]	validation-rmse:6.63832
# [60]	validation-rmse:6.63756
# [61]	validation-rmse:6.63632
# [62]	validation-rmse:6.63592
# [63]	validation-rmse:6.63497
# [64]	validation-rmse:6.63423
# [65]	validation-rmse:6.63325
# [66]	validation-rmse:6.63187
# [67]	validation-rmse:6.63092
# [68]	validation-rmse:6.62869
# [69]	validation-rmse:6.62768
# [70]	validation-rmse:6.62681
# [71]	validation-rmse:6.62623
# [72]	validation-rmse:6.62559
# [73]	validation-rmse:6.62491
# [74]	validation-rmse:6.62417
# [75]	validation-rmse:6.62371
# [76]	validation-rmse:6.62344
# [77]	validation-rmse:6.62312
# [78]	validation-rmse:6.62141
# [79]	validation-rmse:6.62096
# [80]	validation-rmse:6.62026
# [81]	validation-rmse:6.61971
# [82]	validation-rmse:6.61771
# [83]	validation-rmse:6.61684
# [84]	validation-rmse:6.61588
# [85]	validation-rmse:6.61527
# [86]	validation-rmse:6.61462
# [87]	validation-rmse:6.61346
# [88]	validation-rmse:6.61293
# [89]	validation-rmse:6.61236
# [90]	validation-rmse:6.61155
# [91]	validation-rmse:6.61039
# [92]	validation-rmse:6.60970
# [93]	validation-rmse:6.60930
# [94]	validation-rmse:6.60837
# [95]	validation-rmse:6.60640
# [96]	validation-rmse:6.60558
# [97]	validation-rmse:6.60457
# [98]	validation-rmse:6.60416
# [99]	validation-rmse:6.60358
# [100]	validation-rmse:6.60332
# [101]	validation-rmse:6.60311
# [102]	validation-rmse:6.60256
# [103]	validation-rmse:6.60219
# [104]	validation-rmse:6.60156
# [105]	validation-rmse:6.60095
# [106]	validation-rmse:6.60039
# [107]	validation-rmse:6.60013
# [108]	validation-rmse:6.59965
# [109]	validation-rmse:6.59887
# [110]	validation-rmse:6.59811
# [111]	validation-rmse:6.59767
# [112]	validation-rmse:6.59679
# [113]	validation-rmse:6.59605
# [114]	validation-rmse:6.59527
# [115]	validation-rmse:6.59478
# [116]	validation-rmse:6.59436
# [117]	validation-rmse:6.59374
# [118]	validation-rmse:6.59356
# [119]	validation-rmse:6.59321
# [120]	validation-rmse:6.59275
# [121]	validation-rmse:6.59207
# [122]	validation-rmse:6.59156
# [123]	validation-rmse:6.59079
# [124]	validation-rmse:6.59024
# [125]	validation-rmse:6.58917
# [126]	validation-rmse:6.58860
# [127]	validation-rmse:6.58816
# [128]	validation-rmse:6.58719
# [129]	validation-rmse:6.58655
# [130]	validation-rmse:6.58636
# [131]	validation-rmse:6.58582
# [132]	validation-rmse:6.58541
# [133]	validation-rmse:6.58455
# [134]	validation-rmse:6.58407
# [135]	validation-rmse:6.58345
# [136]	validation-rmse:6.58275
# [137]	validation-rmse:6.58219
# [138]	validation-rmse:6.58195
# [139]	validation-rmse:6.58161
# [140]	validation-rmse:6.58094
# [141]	validation-rmse:6.58037
# [142]	validation-rmse:6.58010
# [143]	validation-rmse:6.57942
# [144]	validation-rmse:6.57862
# [145]	validation-rmse:6.57781
# [146]	validation-rmse:6.57753
# [147]	validation-rmse:6.57660
# [148]	validation-rmse:6.57571
# [149]	validation-rmse:6.57519
# [150]	validation-rmse:6.57502
# [151]	validation-rmse:6.57347
# [152]	validation-rmse:6.57322
# [153]	validation-rmse:6.57291
# [154]	validation-rmse:6.57251
# [155]	validation-rmse:6.57169
# [156]	validation-rmse:6.57117
# [157]	validation-rmse:6.57050
# [250]	validation-rmse:6.53136
# [251]	validation-rmse:6.53101
# [252]	validation-rmse:6.53029
# [253]	validation-rmse:6.53031
# [254]	validation-rmse:6.53003
# [255]	validation-rmse:6.52923
# [256]	validation-rmse:6.52890
# [257]	validation-rmse:6.52834
# [258]	validation-rmse:6.52772
# [259]	validation-rmse:6.52767
# [260]	validation-rmse:6.52714
# [261]	validation-rmse:6.52636
# [262]	validation-rmse:6.52594
# [263]	validation-rmse:6.52560
# [264]	validation-rmse:6.52534
# [265]	validation-rmse:6.52508
# [266]	validation-rmse:6.52483
# [267]	validation-rmse:6.52433
# [268]	validation-rmse:6.52399
# [269]	validation-rmse:6.52360
# [270]	validation-rmse:6.52326
# [271]	validation-rmse:6.52248
# [272]	validation-rmse:6.52190
# [273]	validation-rmse:6.52084
# [274]	validation-rmse:6.52034
# [275]	validation-rmse:6.51999
# [276]	validation-rmse:6.51983
# [277]	validation-rmse:6.51975
# [278]	validation-rmse:6.51967
# [279]	validation-rmse:6.51958
# [280]	validation-rmse:6.51930
# [281]	validation-rmse:6.51896
# [282]	validation-rmse:6.51853
# [283]	validation-rmse:6.51828
# [284]	validation-rmse:6.51786
# [285]	validation-rmse:6.51764
# [286]	validation-rmse:6.51719
# [287]	validation-rmse:6.51703
# [288]	validation-rmse:6.51672
# [289]	validation-rmse:6.51665
# [290]	validation-rmse:6.51609
# [291]	validation-rmse:6.51572
# [292]	validation-rmse:6.51528
# [293]	validation-rmse:6.51490
# [294]	validation-rmse:6.51468
# [295]	validation-rmse:6.51426
# [296]	validation-rmse:6.51400
# [297]	validation-rmse:6.51355
# [298]	validation-rmse:6.51333
# [299]	validation-rmse:6.51303
# [300]	validation-rmse:6.51282
# [301]	validation-rmse:6.51216
# [302]	validation-rmse:6.51150
# [303]	validation-rmse:6.51113
# [304]	validation-rmse:6.51053
# [305]	validation-rmse:6.51040
# [306]	validation-rmse:6.51003
# [307]	validation-rmse:6.50947
# [308]	validation-rmse:6.50908
# [309]	validation-rmse:6.50857
# [310]	validation-rmse:6.50832
# [311]	validation-rmse:6.50795
# [312]	validation-rmse:6.50774
# [313]	validation-rmse:6.50745
# [314]	validation-rmse:6.50722
# [315]	validation-rmse:6.50722
# [316]	validation-rmse:6.50673
# [317]	validation-rmse:6.50626
# [318]	validation-rmse:6.50614
# [319]	validation-rmse:6.50586
# [320]	validation-rmse:6.50555
# [321]	validation-rmse:6.50539
# [322]	validation-rmse:6.50542
# [323]	validation-rmse:6.50510
# [324]	validation-rmse:6.50457
# [325]	validation-rmse:6.50396
# [326]	validation-rmse:6.50381
# [327]	validation-rmse:6.50350
# [328]	validation-rmse:6.50315
# [329]	validation-rmse:6.50264
# [330]	validation-rmse:6.50239
# [331]	validation-rmse:6.50213
# [332]	validation-rmse:6.50207
# [333]	validation-rmse:6.50165
# [334]	validation-rmse:6.50162
# [335]	validation-rmse:6.50152
# [336]	validation-rmse:6.50125
# [337]	validation-rmse:6.50103
# [338]	validation-rmse:6.50076
# [339]	validation-rmse:6.50039
# [340]	validation-rmse:6.49992
# [433]	validation-rmse:6.47534
# [434]	validation-rmse:6.47459
# [435]	validation-rmse:6.47413
# [436]	validation-rmse:6.47365
# [437]	validation-rmse:6.47328
# [438]	validation-rmse:6.47302
# [439]	validation-rmse:6.47283
# [440]	validation-rmse:6.47242
# [441]	validation-rmse:6.47240
# [442]	validation-rmse:6.47237
# [443]	validation-rmse:6.47215
# [444]	validation-rmse:6.47204
# [445]	validation-rmse:6.47184
# [446]	validation-rmse:6.47150
# [447]	validation-rmse:6.47093
# [448]	validation-rmse:6.47061
# [449]	validation-rmse:6.47035
# [450]	validation-rmse:6.47035
# [451]	validation-rmse:6.47020
# [452]	validation-rmse:6.47005
# [453]	validation-rmse:6.46976
# [454]	validation-rmse:6.46972
# [455]	validation-rmse:6.46960
# [456]	validation-rmse:6.46930
# [457]	validation-rmse:6.46910
# [458]	validation-rmse:6.46892
# [459]	validation-rmse:6.46876
# [460]	validation-rmse:6.46838
# [461]	validation-rmse:6.46819
# [462]	validation-rmse:6.46795
# [463]	validation-rmse:6.46792
# [464]	validation-rmse:6.46755
# [465]	validation-rmse:6.46732
# [466]	validation-rmse:6.46716
# [467]	validation-rmse:6.46696
# [468]	validation-rmse:6.46676
# [469]	validation-rmse:6.46640
# [470]	validation-rmse:6.46628
# [471]	validation-rmse:6.46593
# [472]	validation-rmse:6.46581
# [473]	validation-rmse:6.46547
# [474]	validation-rmse:6.46507
# [475]	validation-rmse:6.46478
# [476]	validation-rmse:6.46429
# [477]	validation-rmse:6.46379
# [478]	validation-rmse:6.46336
# [479]	validation-rmse:6.46309
# [480]	validation-rmse:6.46282
# [481]	validation-rmse:6.46266
# [482]	validation-rmse:6.46259
# [483]	validation-rmse:6.46203
# [484]	validation-rmse:6.46177
# [485]	validation-rmse:6.46156
# [486]	validation-rmse:6.46156
# [487]	validation-rmse:6.46132
# [488]	validation-rmse:6.46124
# [489]	validation-rmse:6.46116
# [490]	validation-rmse:6.46108
# [491]	validation-rmse:6.46093
# [492]	validation-rmse:6.46080
# [493]	validation-rmse:6.46053
# [494]	validation-rmse:6.46037
# [495]	validation-rmse:6.46045
# [496]	validation-rmse:6.46027
# [497]	validation-rmse:6.46008
# [498]	validation-rmse:6.45982
# [499]	validation-rmse:6.45974
# [500]	validation-rmse:6.45968
# [501]	validation-rmse:6.45944
# [502]	validation-rmse:6.45919
# [503]	validation-rmse:6.45877
# [504]	validation-rmse:6.45846
# [505]	validation-rmse:6.45835
# [506]	validation-rmse:6.45817
# [507]	validation-rmse:6.45776
# [508]	validation-rmse:6.45746
# [509]	validation-rmse:6.45743
# [510]	validation-rmse:6.45728
# [511]	validation-rmse:6.45702
# [512]	validation-rmse:6.45620
# [513]	validation-rmse:6.45603
# [514]	validation-rmse:6.45584
# [515]	validation-rmse:6.45579
# [516]	validation-rmse:6.45582
# [517]	validation-rmse:6.45559
# [518]	validation-rmse:6.45554
# [519]	validation-rmse:6.45546
# [520]	validation-rmse:6.45498
# [521]	validation-rmse:6.45473
# [522]	validation-rmse:6.45455
# [523]	validation-rmse:6.45433
# [524]	validation-rmse:6.45425
# [525]	validation-rmse:6.45408
# [526]	validation-rmse:6.45380
# [527]	validation-rmse:6.45384
# [528]	validation-rmse:6.45363
# [529]	validation-rmse:6.45353
# [530]	validation-rmse:6.45327
# [531]	validation-rmse:6.45292
# [532]	validation-rmse:6.45278
# [533]	validation-rmse:6.45278
# [534]	validation-rmse:6.45254
# [535]	validation-rmse:6.45234
# [536]	validation-rmse:6.45197
# [537]	validation-rmse:6.45182
# [538]	validation-rmse:6.45179
# [539]	validation-rmse:6.45147
# [540]	validation-rmse:6.45138
# [541]	validation-rmse:6.45115
# [542]	validation-rmse:6.45110
# [543]	validation-rmse:6.45098
# [544]	validation-rmse:6.45065
# [545]	validation-rmse:6.45045
# [546]	validation-rmse:6.45028
# [547]	validation-rmse:6.45011
# [548]	validation-rmse:6.44916
# [549]	validation-rmse:6.44911
# [550]	validation-rmse:6.44886
# [551]	validation-rmse:6.44846
# [552]	validation-rmse:6.44838
# [553]	validation-rmse:6.44832
# [554]	validation-rmse:6.44812
# [555]	validation-rmse:6.44815
# [556]	validation-rmse:6.44812
# [557]	validation-rmse:6.44790
# [558]	validation-rmse:6.44771
# [559]	validation-rmse:6.44742
# [560]	validation-rmse:6.44737
# [561]	validation-rmse:6.44742
# [562]	validation-rmse:6.44718
# [563]	validation-rmse:6.44674
# [564]	validation-rmse:6.44640
# [565]	validation-rmse:6.44631
# [566]	validation-rmse:6.44621
# [567]	validation-rmse:6.44614
# [568]	validation-rmse:6.44594
# [569]	validation-rmse:6.44574
# [570]	validation-rmse:6.44570
# [571]	validation-rmse:6.44525
# [572]	validation-rmse:6.44481
# [573]	validation-rmse:6.44455
# [574]	validation-rmse:6.44424
# [575]	validation-rmse:6.44412
# [576]	validation-rmse:6.44389
# [577]	validation-rmse:6.44366
# [578]	validation-rmse:6.44337
# [579]	validation-rmse:6.44311
# [580]	validation-rmse:6.44293
# [581]	validation-rmse:6.44264
# [582]	validation-rmse:6.44239
# [583]	validation-rmse:6.44231
# [584]	validation-rmse:6.44228
# [585]	validation-rmse:6.44203
# [586]	validation-rmse:6.44171
# [587]	validation-rmse:6.44145
# [588]	validation-rmse:6.44137
# [589]	validation-rmse:6.44108
# [590]	validation-rmse:6.44079
# [591]	validation-rmse:6.44053
# [592]	validation-rmse:6.44040
# [593]	validation-rmse:6.44026
# [594]	validation-rmse:6.44011
# [595]	validation-rmse:6.43995
# [596]	validation-rmse:6.43974
# [597]	validation-rmse:6.43981
# [598]	validation-rmse:6.43965
# [599]	validation-rmse:6.43935
# [600]	validation-rmse:6.43911
# [601]	validation-rmse:6.43927
# [602]	validation-rmse:6.43913
# [603]	validation-rmse:6.43893
# [604]	validation-rmse:6.43884
# [605]	validation-rmse:6.43859
# [606]	validation-rmse:6.43837
# [607]	validation-rmse:6.43829
# [608]	validation-rmse:6.43818
# [609]	validation-rmse:6.43792
# [610]	validation-rmse:6.43772
# [611]	validation-rmse:6.43745
# [612]	validation-rmse:6.43715
# [613]	validation-rmse:6.43716
# [614]	validation-rmse:6.43678
# [615]	validation-rmse:6.43654
# [707]	validation-rmse:6.42016
# [708]	validation-rmse:6.42023
# [709]	validation-rmse:6.42007
# [710]	validation-rmse:6.41959
# [711]	validation-rmse:6.41951
# [712]	validation-rmse:6.41936
# [713]	validation-rmse:6.41922
# [714]	validation-rmse:6.41901
# [715]	validation-rmse:6.41889
# [716]	validation-rmse:6.41868
# [717]	validation-rmse:6.41859
# [718]	validation-rmse:6.41858
# [719]	validation-rmse:6.41844
# [720]	validation-rmse:6.41835
# [721]	validation-rmse:6.41833
# [722]	validation-rmse:6.41826
# [723]	validation-rmse:6.41800
# [724]	validation-rmse:6.41785
# [725]	validation-rmse:6.41766
# [726]	validation-rmse:6.41774
# [727]	validation-rmse:6.41760
# [728]	validation-rmse:6.41764
# [729]	validation-rmse:6.41762
# [730]	validation-rmse:6.41706
# [731]	validation-rmse:6.41649
# [732]	validation-rmse:6.41628
# [733]	validation-rmse:6.41611
# [734]	validation-rmse:6.41580
# [735]	validation-rmse:6.41571
# [736]	validation-rmse:6.41554
# [737]	validation-rmse:6.41538
# [738]	validation-rmse:6.41543
# [739]	validation-rmse:6.41540
# [740]	validation-rmse:6.41542
# [741]	validation-rmse:6.41509
# [742]	validation-rmse:6.41503
# [743]	validation-rmse:6.41409
# [744]	validation-rmse:6.41403
# [745]	validation-rmse:6.41401
# [746]	validation-rmse:6.41382
# [747]	validation-rmse:6.41358
# [748]	validation-rmse:6.41351
# [749]	validation-rmse:6.41338
# [750]	validation-rmse:6.41332
# [751]	validation-rmse:6.41308
# [752]	validation-rmse:6.41312
# [753]	validation-rmse:6.41286
# [754]	validation-rmse:6.41274
# [755]	validation-rmse:6.41268
# [756]	validation-rmse:6.41271
# [757]	validation-rmse:6.41264
# [758]	validation-rmse:6.41248
# [759]	validation-rmse:6.41254
# [760]	validation-rmse:6.41233
# [761]	validation-rmse:6.41203
# [762]	validation-rmse:6.41200
# [763]	validation-rmse:6.41207
# [764]	validation-rmse:6.41200
# [765]	validation-rmse:6.41188
# [766]	validation-rmse:6.41163
# [767]	validation-rmse:6.41141
# [768]	validation-rmse:6.41076
# [769]	validation-rmse:6.41083
# [770]	validation-rmse:6.41070
# [771]	validation-rmse:6.41043
# [772]	validation-rmse:6.41035
# [773]	validation-rmse:6.41036
# [774]	validation-rmse:6.41024
# [775]	validation-rmse:6.41039
# [776]	validation-rmse:6.41034
# [777]	validation-rmse:6.41025
# [778]	validation-rmse:6.41018
# [779]	validation-rmse:6.40994
# [780]	validation-rmse:6.40988
# [781]	validation-rmse:6.40977
# [782]	validation-rmse:6.40964
# [783]	validation-rmse:6.40951
# [784]	validation-rmse:6.40959
# [785]	validation-rmse:6.40934
# [786]	validation-rmse:6.40913
# [787]	validation-rmse:6.40904
# [788]	validation-rmse:6.40881
# [789]	validation-rmse:6.40865
# [790]	validation-rmse:6.40857
# [791]	validation-rmse:6.40859
# [792]	validation-rmse:6.40877
# [793]	validation-rmse:6.40858
# [794]	validation-rmse:6.40833
# [795]	validation-rmse:6.40827
# [796]	validation-rmse:6.40824
# [797]	validation-rmse:6.40814
# [798]	validation-rmse:6.40787
# [799]	validation-rmse:6.40765
# [800]	validation-rmse:6.40756
# [801]	validation-rmse:6.40745
# [802]	validation-rmse:6.40735
# [803]	validation-rmse:6.40733
# [804]	validation-rmse:6.40716
# [805]	validation-rmse:6.40695
# [806]	validation-rmse:6.40679
# [807]	validation-rmse:6.40659
# [808]	validation-rmse:6.40666
# [809]	validation-rmse:6.40663
# [810]	validation-rmse:6.40644
# [811]	validation-rmse:6.40629
# [812]	validation-rmse:6.40621
# [813]	validation-rmse:6.40617
# [814]	validation-rmse:6.40596
# [815]	validation-rmse:6.40583
# [816]	validation-rmse:6.40564
# [817]	validation-rmse:6.40554
# [818]	validation-rmse:6.40560
# [819]	validation-rmse:6.40533
# [820]	validation-rmse:6.40487
# [821]	validation-rmse:6.40470
# [822]	validation-rmse:6.40451
# [823]	validation-rmse:6.40451
# [824]	validation-rmse:6.40439
# [825]	validation-rmse:6.40426
# [826]	validation-rmse:6.40406
# [827]	validation-rmse:6.40382
# [828]	validation-rmse:6.40373
# [829]	validation-rmse:6.40359
# [830]	validation-rmse:6.40348
# [831]	validation-rmse:6.40348
# [832]	validation-rmse:6.40331
# [833]	validation-rmse:6.40314
# [834]	validation-rmse:6.40306
# [835]	validation-rmse:6.40290
# [836]	validation-rmse:6.40262
# [837]	validation-rmse:6.40264
# [838]	validation-rmse:6.40250
# [839]	validation-rmse:6.40250
# [840]	validation-rmse:6.40243
# [841]	validation-rmse:6.40215
# [842]	validation-rmse:6.40200
# [843]	validation-rmse:6.40182
# [844]	validation-rmse:6.40172
# [845]	validation-rmse:6.40170
# [846]	validation-rmse:6.40165
# [847]	validation-rmse:6.40161
# [848]	validation-rmse:6.40144
# [849]	validation-rmse:6.40143
# [850]	validation-rmse:6.40128
# [851]	validation-rmse:6.40109
# [852]	validation-rmse:6.40097
# [853]	validation-rmse:6.40075
# [854]	validation-rmse:6.40071
# [855]	validation-rmse:6.40094
# [856]	validation-rmse:6.40088
# [857]	validation-rmse:6.40077
# [858]	validation-rmse:6.40081
# [859]	validation-rmse:6.40067
# [860]	validation-rmse:6.40053
# [861]	validation-rmse:6.40026
# [862]	validation-rmse:6.40017
# [863]	validation-rmse:6.40003
# [864]	validation-rmse:6.39985
# [865]	validation-rmse:6.39961
# [866]	validation-rmse:6.39919
# [867]	validation-rmse:6.39907
# [868]	validation-rmse:6.39908
# [869]	validation-rmse:6.39901
# [870]	validation-rmse:6.39881
# [871]	validation-rmse:6.39858
# [872]	validation-rmse:6.39860
# [873]	validation-rmse:6.39839
# [874]	validation-rmse:6.39805
# [875]	validation-rmse:6.39789
# [876]	validation-rmse:6.39787
# [877]	validation-rmse:6.39772
# [878]	validation-rmse:6.39757
# [879]	validation-rmse:6.39746
# [880]	validation-rmse:6.39717
# [881]	validation-rmse:6.39695
# [882]	validation-rmse:6.39683
# [883]	validation-rmse:6.39684
# [884]	validation-rmse:6.39666
# [885]	validation-rmse:6.39660
# [886]	validation-rmse:6.39642
# [887]	validation-rmse:6.39613
# [888]	validation-rmse:6.39602
# [889]	validation-rmse:6.39597
# [982]	validation-rmse:6.38485
# [983]	validation-rmse:6.38491
# [984]	validation-rmse:6.38477
# [985]	validation-rmse:6.38487
# [986]	validation-rmse:6.38498
# [987]	validation-rmse:6.38487
# [988]	validation-rmse:6.38471
# [989]	validation-rmse:6.38473
# [990]	validation-rmse:6.38463
# [991]	validation-rmse:6.38450
# [992]	validation-rmse:6.38433
# [993]	validation-rmse:6.38412
# [994]	validation-rmse:6.38392
# [995]	validation-rmse:6.38368
# [996]	validation-rmse:6.38358
# [997]	validation-rmse:6.38348
# [998]	validation-rmse:6.38339
# [999]	validation-rmse:6.38341
# 2025/06/29 03:43:11 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# /home/codespace/anaconda3/envs/week2-env/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [03:43:11] WARNING: /workspace/src/c_api/c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   warnings.warn(smsg, UserWarning)
# 2025/06/29 03:43:14 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.

# %%
# second way to save model 
with mlflow.start_run(): 

    # include the preprocessing steps 
    train = xgb.DMatrix(X_train, label=y_train)
    valid = xgb.DMatrix(X_val, label=y_val)

    params = {
        'learning_rate': 0.1557567395831292,
        'max_depth': 10,
        'min_child_weight': 1.716416307091764,
        'objective': 'reg:linear',
        'reg_alpha': 0.027589494435073993,
        'reg_lambda': 0.05813256739773465,
        'seed': 42
    }


    mlflow.log_params(params)

    booster = xgb.train(
                params=params,
                dtrain=train,
                num_boost_round=1000,
                evals=[(valid, 'validation')],
                early_stopping_rounds=50
            )

    y_pred = booster.predict(valid)
    rmse = root_mean_squared_error(y_val,y_pred)
    mlflow.log_metric("rmse",rmse)

    with open("models/preprocessor.b","wb") as f_out: 
        pickle.dump(dv, f_out) # save the dv, which is the vectorisor 

    mlflow.log_artifact("models/preprocessor.b",artifact_path="preprocessor")

    mlflow.xgboost.log_model(booster,artifact_path="models_mlflow")
# Out:
# /home/codespace/anaconda3/envs/week2-env/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [13:31:17] WARNING: /workspace/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:10.99990
# [1]	validation-rmse:10.03189
# [2]	validation-rmse:9.26994
# [3]	validation-rmse:8.67609
# [4]	validation-rmse:8.21642
# [5]	validation-rmse:7.86089
# [6]	validation-rmse:7.59085
# [7]	validation-rmse:7.38312
# [8]	validation-rmse:7.22599
# [9]	validation-rmse:7.10573
# [10]	validation-rmse:7.01421
# [11]	validation-rmse:6.94278
# [12]	validation-rmse:6.88631
# [13]	validation-rmse:6.84316
# [14]	validation-rmse:6.80932
# [15]	validation-rmse:6.78308
# [16]	validation-rmse:6.76281
# [17]	validation-rmse:6.74500
# [18]	validation-rmse:6.73210
# [19]	validation-rmse:6.72066
# [20]	validation-rmse:6.71122
# [21]	validation-rmse:6.70148
# [22]	validation-rmse:6.69493
# [23]	validation-rmse:6.69017
# [24]	validation-rmse:6.68575
# [25]	validation-rmse:6.68172
# [26]	validation-rmse:6.67870
# [27]	validation-rmse:6.67550
# [28]	validation-rmse:6.67444
# [29]	validation-rmse:6.67192
# [30]	validation-rmse:6.67075
# [31]	validation-rmse:6.66982
# [32]	validation-rmse:6.66859
# [33]	validation-rmse:6.66760
# [34]	validation-rmse:6.66669
# [35]	validation-rmse:6.66601
# [36]	validation-rmse:6.66283
# [37]	validation-rmse:6.66143
# [38]	validation-rmse:6.65992
# [39]	validation-rmse:6.65853
# [40]	validation-rmse:6.65715
# [41]	validation-rmse:6.65641
# [42]	validation-rmse:6.65561
# [43]	validation-rmse:6.65459
# [44]	validation-rmse:6.65375
# [45]	validation-rmse:6.65248
# [46]	validation-rmse:6.65134
# [47]	validation-rmse:6.65079
# [48]	validation-rmse:6.64995
# [49]	validation-rmse:6.64865
# [50]	validation-rmse:6.64730
# [51]	validation-rmse:6.64598
# [52]	validation-rmse:6.64529
# [53]	validation-rmse:6.64455
# [54]	validation-rmse:6.64339
# [55]	validation-rmse:6.64208
# [56]	validation-rmse:6.64098
# [57]	validation-rmse:6.64045
# [58]	validation-rmse:6.63931
# [59]	validation-rmse:6.63832
# [60]	validation-rmse:6.63756
# [61]	validation-rmse:6.63632
# [62]	validation-rmse:6.63592
# [63]	validation-rmse:6.63497
# [64]	validation-rmse:6.63423
# [65]	validation-rmse:6.63325
# [66]	validation-rmse:6.63187
# [67]	validation-rmse:6.63092
# [68]	validation-rmse:6.62869
# [69]	validation-rmse:6.62768
# [70]	validation-rmse:6.62681
# [71]	validation-rmse:6.62623
# [72]	validation-rmse:6.62559
# [73]	validation-rmse:6.62491
# [74]	validation-rmse:6.62417
# [75]	validation-rmse:6.62371
# [76]	validation-rmse:6.62344
# [77]	validation-rmse:6.62312
# [78]	validation-rmse:6.62141
# [79]	validation-rmse:6.62096
# [80]	validation-rmse:6.62026
# [81]	validation-rmse:6.61971
# [82]	validation-rmse:6.61771
# [83]	validation-rmse:6.61684
# [84]	validation-rmse:6.61588
# [85]	validation-rmse:6.61527
# [86]	validation-rmse:6.61462
# [87]	validation-rmse:6.61346
# [88]	validation-rmse:6.61293
# [89]	validation-rmse:6.61236
# [90]	validation-rmse:6.61155
# [91]	validation-rmse:6.61039
# [92]	validation-rmse:6.60970
# [93]	validation-rmse:6.60930
# [94]	validation-rmse:6.60837
# [95]	validation-rmse:6.60640
# [96]	validation-rmse:6.60558
# [97]	validation-rmse:6.60457
# [98]	validation-rmse:6.60416
# [99]	validation-rmse:6.60358
# [100]	validation-rmse:6.60332
# [101]	validation-rmse:6.60311
# [102]	validation-rmse:6.60256
# [103]	validation-rmse:6.60219
# [104]	validation-rmse:6.60156
# [105]	validation-rmse:6.60095
# [106]	validation-rmse:6.60039
# [107]	validation-rmse:6.60013
# [108]	validation-rmse:6.59965
# [109]	validation-rmse:6.59887
# [110]	validation-rmse:6.59811
# [111]	validation-rmse:6.59767
# [112]	validation-rmse:6.59679
# [113]	validation-rmse:6.59605
# [114]	validation-rmse:6.59527
# [115]	validation-rmse:6.59478
# [116]	validation-rmse:6.59436
# [117]	validation-rmse:6.59374
# [118]	validation-rmse:6.59356
# [119]	validation-rmse:6.59321
# [120]	validation-rmse:6.59275
# [121]	validation-rmse:6.59207
# [122]	validation-rmse:6.59156
# [123]	validation-rmse:6.59079
# [124]	validation-rmse:6.59024
# [125]	validation-rmse:6.58917
# [126]	validation-rmse:6.58860
# [402]	validation-rmse:6.48407
# [403]	validation-rmse:6.48372
# [404]	validation-rmse:6.48345
# [405]	validation-rmse:6.48306
# [406]	validation-rmse:6.48277
# [407]	validation-rmse:6.48262
# [408]	validation-rmse:6.48222
# [409]	validation-rmse:6.48201
# [410]	validation-rmse:6.48181
# [411]	validation-rmse:6.48169
# [412]	validation-rmse:6.48129
# [413]	validation-rmse:6.48112
# [414]	validation-rmse:6.48073
# [415]	validation-rmse:6.48048
# [416]	validation-rmse:6.47987
# [417]	validation-rmse:6.47967
# [418]	validation-rmse:6.47933
# [419]	validation-rmse:6.47913
# [420]	validation-rmse:6.47893
# [421]	validation-rmse:6.47857
# [422]	validation-rmse:6.47791
# [423]	validation-rmse:6.47785
# [424]	validation-rmse:6.47777
# [425]	validation-rmse:6.47758
# [426]	validation-rmse:6.47758
# [427]	validation-rmse:6.47760
# [428]	validation-rmse:6.47715
# [429]	validation-rmse:6.47696
# [430]	validation-rmse:6.47700
# [431]	validation-rmse:6.47641
# [432]	validation-rmse:6.47574
# [433]	validation-rmse:6.47534
# [434]	validation-rmse:6.47459
# [435]	validation-rmse:6.47413
# [436]	validation-rmse:6.47365
# [437]	validation-rmse:6.47328
# [438]	validation-rmse:6.47302
# [439]	validation-rmse:6.47283
# [440]	validation-rmse:6.47242
# [441]	validation-rmse:6.47240
# [442]	validation-rmse:6.47237
# [443]	validation-rmse:6.47215
# [444]	validation-rmse:6.47204
# [445]	validation-rmse:6.47184
# [446]	validation-rmse:6.47150
# [447]	validation-rmse:6.47093
# [448]	validation-rmse:6.47061
# [449]	validation-rmse:6.47035
# [450]	validation-rmse:6.47035
# [451]	validation-rmse:6.47020
# [452]	validation-rmse:6.47005
# [453]	validation-rmse:6.46976
# [454]	validation-rmse:6.46972
# [455]	validation-rmse:6.46960
# [456]	validation-rmse:6.46930
# [457]	validation-rmse:6.46910
# [458]	validation-rmse:6.46892
# [459]	validation-rmse:6.46876
# [460]	validation-rmse:6.46838
# [461]	validation-rmse:6.46819
# [462]	validation-rmse:6.46795
# [463]	validation-rmse:6.46792
# [464]	validation-rmse:6.46755
# [465]	validation-rmse:6.46732
# [466]	validation-rmse:6.46716
# [467]	validation-rmse:6.46696
# [468]	validation-rmse:6.46676
# [469]	validation-rmse:6.46640
# [470]	validation-rmse:6.46628
# [471]	validation-rmse:6.46593
# [472]	validation-rmse:6.46581
# [473]	validation-rmse:6.46547
# [474]	validation-rmse:6.46507
# [475]	validation-rmse:6.46478
# [476]	validation-rmse:6.46429
# [477]	validation-rmse:6.46379
# [478]	validation-rmse:6.46336
# [479]	validation-rmse:6.46309
# [480]	validation-rmse:6.46282
# [481]	validation-rmse:6.46266
# [482]	validation-rmse:6.46259
# [483]	validation-rmse:6.46203
# [484]	validation-rmse:6.46177
# [485]	validation-rmse:6.46156
# [486]	validation-rmse:6.46156
# [487]	validation-rmse:6.46132
# [488]	validation-rmse:6.46124
# [489]	validation-rmse:6.46116
# [490]	validation-rmse:6.46108
# [491]	validation-rmse:6.46093
# [492]	validation-rmse:6.46080
# [493]	validation-rmse:6.46053
# [494]	validation-rmse:6.46037
# [495]	validation-rmse:6.46045
# [496]	validation-rmse:6.46027
# [497]	validation-rmse:6.46008
# [498]	validation-rmse:6.45982
# [499]	validation-rmse:6.45974
# [500]	validation-rmse:6.45968
# [501]	validation-rmse:6.45944
# [502]	validation-rmse:6.45919
# [503]	validation-rmse:6.45877
# [504]	validation-rmse:6.45846
# [505]	validation-rmse:6.45835
# [506]	validation-rmse:6.45817
# [507]	validation-rmse:6.45776
# [508]	validation-rmse:6.45746
# [509]	validation-rmse:6.45743
# [510]	validation-rmse:6.45728
# [511]	validation-rmse:6.45702
# [512]	validation-rmse:6.45620
# [513]	validation-rmse:6.45603
# [514]	validation-rmse:6.45584
# [515]	validation-rmse:6.45579
# [516]	validation-rmse:6.45582
# [517]	validation-rmse:6.45559
# [518]	validation-rmse:6.45554
# [519]	validation-rmse:6.45546
# [520]	validation-rmse:6.45498
# [521]	validation-rmse:6.45473
# [522]	validation-rmse:6.45455
# [523]	validation-rmse:6.45433
# [524]	validation-rmse:6.45425
# [525]	validation-rmse:6.45408
# [526]	validation-rmse:6.45380
# [527]	validation-rmse:6.45384
# [528]	validation-rmse:6.45363
# [529]	validation-rmse:6.45353
# [530]	validation-rmse:6.45327
# [531]	validation-rmse:6.45292
# [532]	validation-rmse:6.45278
# [533]	validation-rmse:6.45278
# [534]	validation-rmse:6.45254
# [535]	validation-rmse:6.45234
# [536]	validation-rmse:6.45197
# [537]	validation-rmse:6.45182
# [538]	validation-rmse:6.45179
# [539]	validation-rmse:6.45147
# [540]	validation-rmse:6.45138
# [541]	validation-rmse:6.45115
# [542]	validation-rmse:6.45110
# [543]	validation-rmse:6.45098
# [544]	validation-rmse:6.45065
# [545]	validation-rmse:6.45045
# [546]	validation-rmse:6.45028
# [547]	validation-rmse:6.45011
# [548]	validation-rmse:6.44916
# [549]	validation-rmse:6.44911
# [550]	validation-rmse:6.44886
# [551]	validation-rmse:6.44846
# [552]	validation-rmse:6.44838
# [553]	validation-rmse:6.44832
# [554]	validation-rmse:6.44812
# [555]	validation-rmse:6.44815
# [556]	validation-rmse:6.44812
# [557]	validation-rmse:6.44790
# [558]	validation-rmse:6.44771
# [559]	validation-rmse:6.44742
# [560]	validation-rmse:6.44737
# [561]	validation-rmse:6.44742
# [562]	validation-rmse:6.44718
# [563]	validation-rmse:6.44674
# [564]	validation-rmse:6.44640
# [565]	validation-rmse:6.44631
# [566]	validation-rmse:6.44621
# [567]	validation-rmse:6.44614
# [568]	validation-rmse:6.44594
# [569]	validation-rmse:6.44574
# [570]	validation-rmse:6.44570
# [571]	validation-rmse:6.44525
# [572]	validation-rmse:6.44481
# [573]	validation-rmse:6.44455
# [574]	validation-rmse:6.44424
# [575]	validation-rmse:6.44412
# [576]	validation-rmse:6.44389
# [577]	validation-rmse:6.44366
# [578]	validation-rmse:6.44337
# [579]	validation-rmse:6.44311
# [580]	validation-rmse:6.44293
# [581]	validation-rmse:6.44264
# [582]	validation-rmse:6.44239
# [583]	validation-rmse:6.44231
# [584]	validation-rmse:6.44228
# [585]	validation-rmse:6.44203
# [586]	validation-rmse:6.44171
# [587]	validation-rmse:6.44145
# [588]	validation-rmse:6.44137
# [589]	validation-rmse:6.44108
# [590]	validation-rmse:6.44079
# [591]	validation-rmse:6.44053
# [592]	validation-rmse:6.44040
# [593]	validation-rmse:6.44026
# [594]	validation-rmse:6.44011
# [595]	validation-rmse:6.43995
# [596]	validation-rmse:6.43974
# [597]	validation-rmse:6.43981
# [598]	validation-rmse:6.43965
# [599]	validation-rmse:6.43935
# [600]	validation-rmse:6.43911
# [601]	validation-rmse:6.43927
# [602]	validation-rmse:6.43913
# [603]	validation-rmse:6.43893
# [604]	validation-rmse:6.43884
# [605]	validation-rmse:6.43859
# [606]	validation-rmse:6.43837
# [607]	validation-rmse:6.43829
# [608]	validation-rmse:6.43818
# [609]	validation-rmse:6.43792
# [610]	validation-rmse:6.43772
# [611]	validation-rmse:6.43745
# [612]	validation-rmse:6.43715
# [613]	validation-rmse:6.43716
# [614]	validation-rmse:6.43678
# [615]	validation-rmse:6.43654
# [616]	validation-rmse:6.43632
# [617]	validation-rmse:6.43611
# [618]	validation-rmse:6.43600
# [619]	validation-rmse:6.43585
# [620]	validation-rmse:6.43579
# [621]	validation-rmse:6.43559
# [622]	validation-rmse:6.43548
# [623]	validation-rmse:6.43523
# [624]	validation-rmse:6.43516
# [625]	validation-rmse:6.43493
# [626]	validation-rmse:6.43422
# [627]	validation-rmse:6.43408
# [628]	validation-rmse:6.43382
# [629]	validation-rmse:6.43361
# [630]	validation-rmse:6.43343
# [631]	validation-rmse:6.43337
# [632]	validation-rmse:6.43294
# [633]	validation-rmse:6.43290
# [634]	validation-rmse:6.43293
# [635]	validation-rmse:6.43284
# [636]	validation-rmse:6.43282
# [637]	validation-rmse:6.43275
# [638]	validation-rmse:6.43247
# [639]	validation-rmse:6.43215
# [640]	validation-rmse:6.43222
# [641]	validation-rmse:6.43206
# [642]	validation-rmse:6.43190
# [643]	validation-rmse:6.43164
# [644]	validation-rmse:6.43141
# [645]	validation-rmse:6.43111
# [646]	validation-rmse:6.43083
# [647]	validation-rmse:6.43017
# [648]	validation-rmse:6.43003
# [649]	validation-rmse:6.42986
# [650]	validation-rmse:6.42974
# [651]	validation-rmse:6.42957
# [652]	validation-rmse:6.42930
# [653]	validation-rmse:6.42907
# [654]	validation-rmse:6.42876
# [655]	validation-rmse:6.42867
# [656]	validation-rmse:6.42824
# [657]	validation-rmse:6.42808
# [658]	validation-rmse:6.42788
# [659]	validation-rmse:6.42747
# [660]	validation-rmse:6.42738
# [661]	validation-rmse:6.42714
# [662]	validation-rmse:6.42673
# [663]	validation-rmse:6.42654
# [664]	validation-rmse:6.42643
# [665]	validation-rmse:6.42606
# [666]	validation-rmse:6.42598
# [667]	validation-rmse:6.42586
# [668]	validation-rmse:6.42576
# [669]	validation-rmse:6.42578
# [670]	validation-rmse:6.42608
# [671]	validation-rmse:6.42604
# [672]	validation-rmse:6.42592
# [673]	validation-rmse:6.42579
# [674]	validation-rmse:6.42548
# [675]	validation-rmse:6.42529
# [676]	validation-rmse:6.42537
# [677]	validation-rmse:6.42528
# [678]	validation-rmse:6.42503
# [679]	validation-rmse:6.42433
# [680]	validation-rmse:6.42434
# [681]	validation-rmse:6.42441
# [682]	validation-rmse:6.42439
# [683]	validation-rmse:6.42419
# [684]	validation-rmse:6.42416
# [685]	validation-rmse:6.42401
# [686]	validation-rmse:6.42381
# [687]	validation-rmse:6.42372
# [688]	validation-rmse:6.42362
# [689]	validation-rmse:6.42329
# [690]	validation-rmse:6.42326
# [691]	validation-rmse:6.42317
# [692]	validation-rmse:6.42305
# [693]	validation-rmse:6.42275
# [694]	validation-rmse:6.42255
# [695]	validation-rmse:6.42247
# [696]	validation-rmse:6.42225
# [697]	validation-rmse:6.42199
# [698]	validation-rmse:6.42175
# [699]	validation-rmse:6.42151
# [700]	validation-rmse:6.42115
# [701]	validation-rmse:6.42086
# [702]	validation-rmse:6.42057
# [703]	validation-rmse:6.42021
# [704]	validation-rmse:6.42013
# [705]	validation-rmse:6.42015
# [706]	validation-rmse:6.42027
# [707]	validation-rmse:6.42016
# [708]	validation-rmse:6.42023
# [709]	validation-rmse:6.42007
# [710]	validation-rmse:6.41959
# [711]	validation-rmse:6.41951
# [712]	validation-rmse:6.41936
# [713]	validation-rmse:6.41922
# [714]	validation-rmse:6.41901
# [715]	validation-rmse:6.41889
# [716]	validation-rmse:6.41868
# [717]	validation-rmse:6.41859
# [718]	validation-rmse:6.41858
# [719]	validation-rmse:6.41844
# [720]	validation-rmse:6.41835
# [721]	validation-rmse:6.41833
# [722]	validation-rmse:6.41826
# [723]	validation-rmse:6.41800
# [724]	validation-rmse:6.41785
# [725]	validation-rmse:6.41766
# [726]	validation-rmse:6.41774
# [727]	validation-rmse:6.41760
# [728]	validation-rmse:6.41764
# [729]	validation-rmse:6.41762
# [730]	validation-rmse:6.41706
# [731]	validation-rmse:6.41649
# [732]	validation-rmse:6.41628
# [733]	validation-rmse:6.41611
# [734]	validation-rmse:6.41580
# [735]	validation-rmse:6.41571
# [736]	validation-rmse:6.41554
# [737]	validation-rmse:6.41538
# [738]	validation-rmse:6.41543
# [739]	validation-rmse:6.41540
# [740]	validation-rmse:6.41542
# [741]	validation-rmse:6.41509
# [742]	validation-rmse:6.41503
# [743]	validation-rmse:6.41409
# [744]	validation-rmse:6.41403
# [745]	validation-rmse:6.41401
# [746]	validation-rmse:6.41382
# [747]	validation-rmse:6.41358
# [748]	validation-rmse:6.41351
# [749]	validation-rmse:6.41338
# [750]	validation-rmse:6.41332
# [751]	validation-rmse:6.41308
# [752]	validation-rmse:6.41312
# [753]	validation-rmse:6.41286
# [754]	validation-rmse:6.41274
# [755]	validation-rmse:6.41268
# [756]	validation-rmse:6.41271
# [757]	validation-rmse:6.41264
# [758]	validation-rmse:6.41248
# [759]	validation-rmse:6.41254
# [760]	validation-rmse:6.41233
# [761]	validation-rmse:6.41203
# [762]	validation-rmse:6.41200
# [763]	validation-rmse:6.41207
# [764]	validation-rmse:6.41200
# [765]	validation-rmse:6.41188
# [766]	validation-rmse:6.41163
# [767]	validation-rmse:6.41141
# [768]	validation-rmse:6.41076
# [769]	validation-rmse:6.41083
# [770]	validation-rmse:6.41070
# [771]	validation-rmse:6.41043
# [772]	validation-rmse:6.41035
# [773]	validation-rmse:6.41036
# [774]	validation-rmse:6.41024
# [775]	validation-rmse:6.41039
# [776]	validation-rmse:6.41034
# [777]	validation-rmse:6.41025
# [778]	validation-rmse:6.41018
# [779]	validation-rmse:6.40994
# [780]	validation-rmse:6.40988
# [781]	validation-rmse:6.40977
# [782]	validation-rmse:6.40964
# [783]	validation-rmse:6.40951
# [784]	validation-rmse:6.40959
# [785]	validation-rmse:6.40934
# [786]	validation-rmse:6.40913
# [787]	validation-rmse:6.40904
# [788]	validation-rmse:6.40881
# [789]	validation-rmse:6.40865
# [790]	validation-rmse:6.40857
# [791]	validation-rmse:6.40859
# [792]	validation-rmse:6.40877
# [793]	validation-rmse:6.40858
# [794]	validation-rmse:6.40833
# [795]	validation-rmse:6.40827
# [796]	validation-rmse:6.40824
# [797]	validation-rmse:6.40814
# [798]	validation-rmse:6.40787
# [799]	validation-rmse:6.40765
# [800]	validation-rmse:6.40756
# [801]	validation-rmse:6.40745
# [802]	validation-rmse:6.40735
# [803]	validation-rmse:6.40733
# [804]	validation-rmse:6.40716
# [805]	validation-rmse:6.40695
# [806]	validation-rmse:6.40679
# [807]	validation-rmse:6.40659
# [808]	validation-rmse:6.40666
# [809]	validation-rmse:6.40663
# [810]	validation-rmse:6.40644
# [811]	validation-rmse:6.40629
# [812]	validation-rmse:6.40621
# [813]	validation-rmse:6.40617
# [814]	validation-rmse:6.40596
# [815]	validation-rmse:6.40583
# [816]	validation-rmse:6.40564
# [817]	validation-rmse:6.40554
# [818]	validation-rmse:6.40560
# [819]	validation-rmse:6.40533
# [820]	validation-rmse:6.40487
# [821]	validation-rmse:6.40470
# [822]	validation-rmse:6.40451
# [823]	validation-rmse:6.40451
# [824]	validation-rmse:6.40439
# [825]	validation-rmse:6.40426
# [826]	validation-rmse:6.40406
# [827]	validation-rmse:6.40382
# [828]	validation-rmse:6.40373
# [829]	validation-rmse:6.40359
# [830]	validation-rmse:6.40348
# [831]	validation-rmse:6.40348
# [832]	validation-rmse:6.40331
# [833]	validation-rmse:6.40314
# [834]	validation-rmse:6.40306
# [835]	validation-rmse:6.40290
# [836]	validation-rmse:6.40262
# [837]	validation-rmse:6.40264
# [838]	validation-rmse:6.40250
# [839]	validation-rmse:6.40250
# [840]	validation-rmse:6.40243
# [841]	validation-rmse:6.40215
# [842]	validation-rmse:6.40200
# [843]	validation-rmse:6.40182
# [844]	validation-rmse:6.40172
# [845]	validation-rmse:6.40170
# [846]	validation-rmse:6.40165
# [847]	validation-rmse:6.40161
# [848]	validation-rmse:6.40144
# [849]	validation-rmse:6.40143
# [850]	validation-rmse:6.40128
# [851]	validation-rmse:6.40109
# [852]	validation-rmse:6.40097
# [853]	validation-rmse:6.40075
# [854]	validation-rmse:6.40071
# [855]	validation-rmse:6.40094
# [856]	validation-rmse:6.40088
# [857]	validation-rmse:6.40077
# [858]	validation-rmse:6.40081
# [859]	validation-rmse:6.40067
# [860]	validation-rmse:6.40053
# [861]	validation-rmse:6.40026
# [862]	validation-rmse:6.40017
# [863]	validation-rmse:6.40003
# [864]	validation-rmse:6.39985
# [865]	validation-rmse:6.39961
# [866]	validation-rmse:6.39919
# [867]	validation-rmse:6.39907
# [868]	validation-rmse:6.39908
# [869]	validation-rmse:6.39901
# [870]	validation-rmse:6.39881
# [871]	validation-rmse:6.39858
# [872]	validation-rmse:6.39860
# [873]	validation-rmse:6.39839
# [874]	validation-rmse:6.39805
# [875]	validation-rmse:6.39789
# [876]	validation-rmse:6.39787
# [877]	validation-rmse:6.39772
# [878]	validation-rmse:6.39757
# [879]	validation-rmse:6.39746
# [880]	validation-rmse:6.39717
# [881]	validation-rmse:6.39695
# [882]	validation-rmse:6.39683
# [883]	validation-rmse:6.39684
# [884]	validation-rmse:6.39666
# [885]	validation-rmse:6.39660
# [886]	validation-rmse:6.39642
# [887]	validation-rmse:6.39613
# [888]	validation-rmse:6.39602
# [889]	validation-rmse:6.39597
# [890]	validation-rmse:6.39603
# [891]	validation-rmse:6.39579
# [892]	validation-rmse:6.39568
# [893]	validation-rmse:6.39567
# [894]	validation-rmse:6.39543
# [895]	validation-rmse:6.39532
# [896]	validation-rmse:6.39539
# [897]	validation-rmse:6.39520
# [898]	validation-rmse:6.39508
# [899]	validation-rmse:6.39513
# [900]	validation-rmse:6.39498
# [901]	validation-rmse:6.39485
# [902]	validation-rmse:6.39488
# [903]	validation-rmse:6.39481
# [904]	validation-rmse:6.39481
# [905]	validation-rmse:6.39454
# [906]	validation-rmse:6.39416
# [907]	validation-rmse:6.39388
# [908]	validation-rmse:6.39372
# [909]	validation-rmse:6.39358
# [910]	validation-rmse:6.39351
# [911]	validation-rmse:6.39315
# [912]	validation-rmse:6.39309
# [913]	validation-rmse:6.39289
# [914]	validation-rmse:6.39281
# [915]	validation-rmse:6.39265
# [916]	validation-rmse:6.39237
# [917]	validation-rmse:6.39237
# [918]	validation-rmse:6.39223
# [919]	validation-rmse:6.39213
# [920]	validation-rmse:6.39173
# [921]	validation-rmse:6.39155
# [922]	validation-rmse:6.39142
# [923]	validation-rmse:6.39135
# [924]	validation-rmse:6.39111
# [925]	validation-rmse:6.39093
# [926]	validation-rmse:6.39083
# [927]	validation-rmse:6.39072
# [928]	validation-rmse:6.39065
# [929]	validation-rmse:6.39061
# [930]	validation-rmse:6.39052
# [931]	validation-rmse:6.39015
# [932]	validation-rmse:6.39010
# [933]	validation-rmse:6.38998
# [934]	validation-rmse:6.38965
# [935]	validation-rmse:6.38957
# [936]	validation-rmse:6.38936
# [937]	validation-rmse:6.38914
# [938]	validation-rmse:6.38912
# [939]	validation-rmse:6.38893
# [940]	validation-rmse:6.38904
# [941]	validation-rmse:6.38900
# [942]	validation-rmse:6.38893
# [943]	validation-rmse:6.38905
# [944]	validation-rmse:6.38901
# [945]	validation-rmse:6.38893
# [946]	validation-rmse:6.38901
# [947]	validation-rmse:6.38886
# [948]	validation-rmse:6.38885
# [949]	validation-rmse:6.38885
# [950]	validation-rmse:6.38871
# [951]	validation-rmse:6.38868
# [952]	validation-rmse:6.38862
# [953]	validation-rmse:6.38832
# [954]	validation-rmse:6.38824
# [955]	validation-rmse:6.38831
# [956]	validation-rmse:6.38822
# [957]	validation-rmse:6.38819
# [958]	validation-rmse:6.38796
# [959]	validation-rmse:6.38774
# [960]	validation-rmse:6.38759
# [961]	validation-rmse:6.38748
# [962]	validation-rmse:6.38721
# [963]	validation-rmse:6.38714
# [964]	validation-rmse:6.38712
# [965]	validation-rmse:6.38709
# [966]	validation-rmse:6.38696
# [967]	validation-rmse:6.38686
# [968]	validation-rmse:6.38686
# [969]	validation-rmse:6.38682
# [970]	validation-rmse:6.38660
# [971]	validation-rmse:6.38631
# [972]	validation-rmse:6.38640
# [973]	validation-rmse:6.38631
# [974]	validation-rmse:6.38629
# [975]	validation-rmse:6.38605
# [976]	validation-rmse:6.38579
# [977]	validation-rmse:6.38553
# [978]	validation-rmse:6.38537
# [979]	validation-rmse:6.38506
# [980]	validation-rmse:6.38493
# [981]	validation-rmse:6.38478
# [982]	validation-rmse:6.38485
# [983]	validation-rmse:6.38491
# [984]	validation-rmse:6.38477
# [985]	validation-rmse:6.38487
# [986]	validation-rmse:6.38498
# [987]	validation-rmse:6.38487
# [988]	validation-rmse:6.38471
# [989]	validation-rmse:6.38473
# [990]	validation-rmse:6.38463
# [991]	validation-rmse:6.38450
# [992]	validation-rmse:6.38433
# [993]	validation-rmse:6.38412
# [994]	validation-rmse:6.38392
# [995]	validation-rmse:6.38368
# [996]	validation-rmse:6.38358
# [997]	validation-rmse:6.38348
# [998]	validation-rmse:6.38339
# [999]	validation-rmse:6.38341
# 2025/06/25 13:32:43 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# /home/codespace/anaconda3/envs/week2-env/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [13:32:43] WARNING: /workspace/src/c_api/c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   warnings.warn(smsg, UserWarning)
# 2025/06/25 13:32:46 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.

# %% [markdown]
# # 2 ways to log model:
#
# 1. log model as artifact
# 2. use log_model method to log the model

# %%
# used logged model for prediction 
logged_model = 'runs:/adbb0768ce44421fbfdcc58684f578aa/models_mlflow'

loaded_model = mlflow.pyfunc.load_model(logged_model)
# Out:
# Downloading artifacts:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading artifacts:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
loaded_model
# Out:
# mlflow.pyfunc.loaded_model:
#   artifact_path: /workspaces/mlopszoomcamp/week2/mlruns/1/models/m-fc3593cc0a7846e38a8f59e2ff68c450/artifacts
#   flavor: mlflow.xgboost
#   run_id: adbb0768ce44421fbfdcc58684f578aa

# %%
xgboost_model = mlflow.xgboost.load_model(logged_model)
# Out:
# Downloading artifacts:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading artifacts:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
xgboost_model # model becomes an object

# %%
# make prediction
y_pred = xgboost_model.predict(valid) 

# this is not applying the preprocessofr we saved. If we want to use that, need to use pickle to load the saved dv and still include the code for transformation 

# however it is possible to save both together in same artifact and apply f

# %%
y_pred[:10]
# Out:
# array([15.184608,  7.193801, 16.93405 , 24.365328,  9.278277, 17.098824,
#        12.975654,  8.915227,  8.916344, 17.324223], dtype=float32)
